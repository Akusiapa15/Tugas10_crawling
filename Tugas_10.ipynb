# %% [markdown]
# <a href="https://colab.research.google.com/github/Akusiapa15/Tugas10_crawling/blob/main/Tugas_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from csv import writer
import json

# %%
url = "https://catalog-api5.sociolla.com/search?limit=16&skip=0&sort=-created_at&filter=%7B%22categories.id%22:%225d3d502437382b158ee6dda5%22%7D"
response = requests.get(url)
response = response.json()
list_item = response['data']
for element in list_item:
  print(element)
# Out:
# {'_id': '66f540ba90a1bc320ea9c0ab', 'brand': {'id': '5e71a215c0d13934f6948d49', 'name': 'Secondate', 'slug': '816_secondate', 'logo': 'https://images.soco.id/c319596f-bfe5-47f9-92a9-aee67e48a786-.jpg', 'my_soco_sql_id': 14912, 'my_sociolla_sql_id': 816, 'is_active_in_sociolla': True, 'is_active_in_sociolla_vn': False, 'is_active_in_lulla': False, 'is_active_in_carasun': False, 'is_active_in_review': True, 'is_active_in_event_microsite': True, 'country': 'indonesia', 'region': 'southeast-asia'}, 'default_category': {'id': '5d3d502437382b158ee6dda5', 'name': 'Eyeshadow', 'slug': '166-eyeshadow', 'rating_types': ['is_star_long_wear', 'is_star_packaging', 'is_star_pigmentation', 'is_star_texture', 'is_star_value_for_money']}, 'review_stats': {'total_reviews': 0, 'average_rating': 0, 'total_recommended_count': 0, 'total_repurchase_maybe_count': 0, 'total_repurchase_no_count': 0, 'total_repurchase_yes_count': 0}, 'is_active_in_review': True, 'is_active_in_sociolla': True, 'is_active_in_lul
# ...

# %%
with open('/content/sample_data/eyeshadow.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['eyeshadow']
    csv_writer.writerow(headers)

    for item in list_item:
        # Convert the dictionary to a string before replacing newline characters
        item_str = str(item)
        item_str = item_str.replace("\n", "")
        csv_writer.writerow([item_str]) # Write the modified string to the CSV

# %%
with open('/content/sample_data/nweyeshadow.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['eyeshadow']
    csv_writer.writerow(headers)

    for item in list_item:
        # Create the string using f-string formatting for easier readability and flexibility.
        item_str = f"{item.get('_id', '')},{item.get('name', '')},{item.get('region', '')},{item.get('min_price', '')},{item.get('max_price', '')},{item.get('description', '')}"
        item_str = item_str.replace("\n", "")
        csv_writer.writerow([item_str]) # Write the modified string to the CSV
